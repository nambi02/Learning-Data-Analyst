# %%
# Sales Data Analysis Project

# 1. Import Library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Load Dataset
df = pd.read_csv('sales_data.csv', sep=';')

# 3. Quick Look
display(df.head())
print(df.info())
print(df.describe())

# 4. Data Cleaning
# Membuat kolom Total Sales
if 'Total Sales' not in df.columns or df['Total Sales'].isnull().all():
    df['Total Sales'] = df['Quantity'] * df['Unit Price']
    df.to_csv('sales_data.csv', sep=';', index=False)

# 5. Analisis Produk Terlaris
product_sales = df.groupby('Product')['Total Sales'].sum().sort_values(ascending=False)
print(product_sales)

# Visualisasi Produk Terlaris
product_sales.plot(kind='bar', color='skyblue')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# 6. Analisis Kota Terlaris
top_city = df.groupby('City')['Total Sales'].sum().sort_values(ascending=False)
print(top_city)

# Visualisasi Kota Terlaris
top_city.plot(kind='bar', color='lightgreen')
plt.title('Total Sales per City')
plt.xlabel('City')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# 7. Sales Trend Harian
sales_trend = df.groupby('Order Date')['Total Sales'].sum()
sales_trend.plot(kind='line', marker='o', color='orange')
plt.title('Daily Sales Trend')
plt.xlabel('Order Date')
plt.ylabel('Total Sales')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# 8. Conclusion
print("\nConclusion:")
print("- Produk dengan penjualan tertinggi adalah Laptop.")
print("- Kota dengan penjualan tertinggi adalah Jakarta.")
print("- Tren penjualan harian meningkat signifikan menjelang tanggal 10 Januari 2024.")
# Out:
#    Order Date      City     Product  Quantity  Unit Price  Total Sales
# 0  05/01/2024   Jakarta  Smartphone         2         300          600
# 1  06/01/2024   Bandung      Laptop         1         900          900
# 2  07/01/2024  Surabaya  Headphones         3          50          150
# 3  07/01/2024   Jakarta      Tablet         1         400          400
# 4  08/01/2024   Bandung  Smartwatch         4         200          800
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order Date   7 non-null      object
#  1   City         7 non-null      object
#  2   Product      7 non-null      object
#  3   Quantity     7 non-null      int64
#  4   Unit Price   7 non-null      int64
#  5   Total Sales  7 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 468.0+ bytes
# None
#        Quantity  Unit Price  Total Sales
# count  7.000000    7.000000     7.000000
# mean   2.142857  457.142857   792.857143
# std    1.069045  319.411662   497.014899
# min    1.000000   50.000000   150.000000
# 25%    1.500000  250.000000   500.000000
# 50%    2.000000  400.000000   800.000000
# 75%    2.500000  675.000000   950.000000
# max    4.000000  900.000000  1700.000000
# Product
# Laptop        2600
# Camera        1000
# Smartwatch     800
# Smartphone     600
# Tablet         400
# Headphones     150
# Name: Total Sales, dtype: int64
# City
# Jakarta     2700
# Bandung     1700
# Surabaya    1150
# Name: Total Sales, dtype: int64
# Conclusion:
# - Produk dengan penjualan tertinggi adalah Laptop.
# - Kota dengan penjualan tertinggi adalah Jakarta.
# - Tren penjualan harian meningkat signifikan menjelang tanggal 10 Januari 2024.
